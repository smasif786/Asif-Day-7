# %% [markdown]
# 1.Print no. of matches won by each team based on year wise (each year as one column)
#
# 2.Print  ManOfMach count of each player in  Hyderabad stadium
#
# 3.Print number of matches won and loss(as two columns). Consider as win when a team wins Toss  and Match . print for each and every team

# %%
import pandas as pd
a=pd.read_csv(r"C:\Users\HOME\Python\DataFiles\Match.csv")
a.head(2)
# Out:
#    Match_SK  match_id                        Team1                  Team2  \
# 0         0    335987  Royal Challengers Bangalore  Kolkata Knight Riders
# 1         1    335988              Kings XI Punjab    Chennai Super Kings
#
#   match_date  Season_Year                                  Venue_Name  \
# 0  4/18/2008         2008                       M Chinnaswamy Stadium
# 1  4/19/2008         2008  Punjab Cricket Association Stadium, Mohali
#
#     City_Name Country_Name                  Toss_Winner  \
# 0   Bangalore        India  Royal Challengers Bangalore
# 1  Chandigarh        India          Chennai Super Kings
#
#             match_winner Toss_Name Win_Type Outcome_Type    ManOfMach  \
# 0  Kolkata Knight Riders     field     runs       Result  BB McCullum
# 1    Chennai Super Kings       bat     runs       Result   MEK Hussey
#
#    Win_Margin  Country_id
# 0       140.0           1
# 1        33.0           1

# %%
print('The number of matches won by each team in year team')
s= pd.DataFrame(a.groupby(['Season_Year','match_winner'])['match_winner'].count())
s.columns= ['Count']
s= s.reset_index()
s.head()
# Out:
# The number of matches won by each team in year team
#    Season_Year           match_winner  Count
# 0         2008    Chennai Super Kings      9
# 1         2008        Deccan Chargers      2
# 2         2008       Delhi Daredevils      7
# 3         2008        Kings XI Punjab     10
# 4         2008  Kolkata Knight Riders      6

# %%
print('ManOfMach count of each player in Hyderabad stadium')
s= pd.DataFrame(a.groupby(['City_Name','ManOfMach'])['ManOfMach'].count())
s.columns= ['Count']
s
# Out:
# ManOfMach count of each player in Hyderabad stadium
#                                Count
# City_Name     ManOfMach
# Abu Dhabi     AJ Finch             1
#               AM Rahane            1
#               B Kumar              1
#               CA Lynn              1
#               DR Smith             1
#               GJ Maxwell           3
#               JH Kallis            1
#               JP Duminy            1
#               JP Faulkner          1
#               M Vijay              1
#               MM Sharma            1
#               PA Patel             1
#               PV Tambe             1
#               RA Jadeja            1
#               SK Raina             1
#               Sandeep Sharma       2
#               YS Chahal            1
# Ahmedabad     AA Jhunjhunwala      1
#               AM Rahane            2
#               B Kumar              1
#               MA Starc             1
#               MEK Hussey           1
# ...

# %%
s=a[a.City_Name=='Hyderabad']
s
s.ManOfMach.count()
# Out:
# 41

# %%
b=s.ManOfMach.value_counts()
b.head()
# Out:
# DA Warner    6
# DW Steyn     3
# V Sehwag     2
# A Mishra     2
# YK Pathan    2
# Name: ManOfMach, dtype: int64

# %%
#3.Print number of matches won and loss(as two columns). Consider as win when a team wins Toss and Match .
print('The team which has won/loss toss in each game: ')
asi= pd.DataFrame(data.groupby('toss_winner')['toss_winner'].count() 
asi.columns=['Count']
asi=asi.reset_index()
print(asi)
# Out:
#   File "<ipython-input-36-964d2fe53e5f>", line 3
#     asi.columns=['Count']
#       ^
# SyntaxError: invalid syntax
