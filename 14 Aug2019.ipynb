# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
#import scikitlearn as
asi=pd.read_csv(r"C:\Users\HOME\Python\DataFiles\Climate.csv")
asi.head(2)
# Out:
#      Title  \
# 0     CDID
# 1  PreUnit
#
#   UK Claimant Count: People - All ages: Over 6 and up to 12 months - SA (000s)  \
# 0                                               AGMC
# 1                                                NaN
#
#   UK Claimant Count: People: All over 12 months - SA (000s)                 \
# 0                                               AGMD
# 1                                                NaN
#
#   UK Claimant Count: Men - 25-49yrs: All computerised claims - SA (000s)    \
# 0                                               AGMA
# 1                                                NaN
#
#   Regional claimant count rate NSA % : North East                           \
# 0                                               DPDA
# 1                                                NaN
#
#   UK Claimant Count: People - All ages: Up to 6 months - SA (000s)          \
# 0                                               AGLZ
# ...

# %%
asi =asi.drop(["Title"],axis=1,inplace=False)
asi.head(2)
# Out:
#   UK Claimant Count: People - All ages: Over 6 and up to 12 months - SA (000s)  \
# 0                                               AGMC
# 1                                                NaN
#
#   UK Claimant Count: People: All over 12 months - SA (000s)                 \
# 0                                               AGMD
# 1                                                NaN
#
#   UK Claimant Count: Men - 25-49yrs: All computerised claims - SA (000s)    \
# 0                                               AGMA
# 1                                                NaN
#
#   Regional claimant count rate NSA % : North East                           \
# 0                                               DPDA
# 1                                                NaN
#
#   UK Claimant Count: People - All ages: Up to 6 months - SA (000s)          \
# 0                                               AGLZ
# 1                                                NaN
#
# ...

# %%
X = asi.iloc[:,1:]
X.astype(str)
X.head()
# Out:
#   UK Claimant Count: People: All over 12 months - SA (000s)                 \
# 0                                               AGMD
# 1                                                NaN
# 2                                                NaN
# 3                                         16-03-2016
# 4                                       20 July 2016
#
#   UK Claimant Count: Men - 25-49yrs: All computerised claims - SA (000s)    \
# 0                                               AGMA
# 1                                                NaN
# 2                                                NaN
# 3                                         16-03-2016
# 4                                       20 July 2016
#
#   Regional claimant count rate NSA % : North East                           \
# 0                                               DPDA
# 1                                                NaN
# 2                                                NaN
# ...

# %%
y =asi.iloc[:,1]
y.head(2)
# Out:
# 0    AGMD
# 1     NaN
# Name: UK Claimant Count: People: All over 12 months - SA (000s)               , dtype: object

# %%
# filling the missing value with most occuring value    
asi.iloc[:,:] = asi.iloc[:,:].apply(lambda x:x.fillna(x.value_counts().index[1]))
#claimants3.SEATBELT = claimants1.SEATBELT.fillna(claimants1.SEATBELT.value_counts().index[0])
asi.isnull().sum()
# Out:
# UK Claimant Count: People - All ages: Over 6 and up to 12 months - SA (000s)        0
# UK Claimant Count: People: All over 12 months - SA (000s)                           0
# UK Claimant Count: Men - 25-49yrs: All computerised claims - SA (000s)              0
# Regional claimant count rate NSA % : North East                                     0
# UK Claimant Count: People - All ages: Up to 6 months - SA (000s)                    0
# UK Claimant Count - total computerised claims - People - SA (000s)                  0
# Regional Claimant count rate NSA % : East                                           0
# Regional Claimant count rate NSA % : London                                         0
# Regional Claimant count rate NSA % : South East (GOR)                               0
# Regional Claimant count SA: North East - thousands                                  0
# Regional Claimant count SA: East - thousands                                        0
# ...

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size = 0.3, random_state = 2)

# %%
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (623, 312)
# (267, 312)
# (623,)
# (267,)

# %%
from sklearn.linear_model import LogisticRegression
reg = LogisticRegression()
reg.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-24-8a7fe30342a2> in <module>()
#       1 from sklearn.linear_model import LogisticRegression
#       2 reg = LogisticRegression()
# ----> 3 reg.fit(X_train, y_train)
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py in fit(self, X, y, sample_weight)
#    1218
#    1219         X, y = check_X_y(X, y, accept_sparse='csr', dtype=_dtype,
# -> 1220                          order="C")
#    1221         check_classification_targets(y)
#    1222         self.classes_ = np.unique(y)
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py in check_X_y(X, y, accept_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, warn_on_dtype, estimator)
# ...

# %%
pred = reg.predict(X_test)
pred
# Out:
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# <ipython-input-25-edd409e2f47a> in <module>()
# ----> 1 pred = reg.predict(X_test)
#       2 pred
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\base.py in predict(self, X)
#     322             Predicted class label per sample.
#     323         """
# --> 324         scores = self.decision_function(X)
#     325         if len(scores.shape) == 1:
#     326             indices = (scores > 0).astype(np.int)
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\base.py in decision_function(self, X)
#     296         if not hasattr(self, 'coef_') or self.coef_ is None:
#     297             raise NotFittedError("This %(name)s instance is not fitted "
# --> 298                                  "yet" % {'name': type(self).__name__})
#     299
#     300         X = check_array(X, accept_sparse='csr')
#
# ...

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\HOME\\Python'
