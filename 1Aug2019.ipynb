# %%
import pandas as pd
import numpy as np
Apple=pd.read_csv(r'C:\Users\HOME\Python\AppleStore.csv')
Apple.head()
# Out:
#           id                                         track_name  size_bytes  \
# 0  281656475                                    PAC-MAN Premium   100788224
# 1  281796108                          Evernote - stay organized   158578688
# 2  281940292    WeatherBug - Local Weather, Radar, Maps, Alerts   100524032
# 3  282614216  eBay: Best App to Buy, Sell, Save! Online Shop...   128512000
# 4  282935706                                              Bible    92774400
#
#   currency  price  rating_count_tot  rating_count_ver  user_rating  \
# 0      USD   3.99             21292                26          4.0
# 1      USD   0.00            161065                26          4.0
# 2      USD   0.00            188583              2822          3.5
# 3      USD   0.00            262241               649          4.0
# 4      USD   0.00            985920              5320          4.5
#
#    user_rating_ver     ver cont_rating   prime_genre  sup_devices.num  \
# ...

# %%
Apple.track_name.unique()
# Out:
# array(['PAC-MAN Premium', 'Evernote - stay organized',
#        'WeatherBug - Local Weather, Radar, Maps, Alerts', ...,
#        'Bret Michaels Emojis + Lyric Keyboard',
#        'VR Roller Coaster World - Virtual Reality',
#        'Escape the Sweet Shop Series'], dtype=object)

# %%
Apple = Apple.sort_values('rating_count_tot', ascending=False)
subset_Apple =Apple[:10]
print(subset_Apple.track_name, subset_Apple.rating_count_tot, "bar", "TOP 10 APPS ON THE BASIS OF TOTAL RATINGS",
          "APP NAME", "RATING COUNT (TOTAL)")
# Out:
# 16                     Facebook
# 519                   Instagram
# 1346             Clash of Clans
# 707                  Temple Run
# 7       Pandora - Music & Radio
# 755                   Pinterest
# 4                         Bible
# 1493           Candy Crush Saga
# 178               Spotify Music
# 275                 Angry Birds
# Name: track_name, dtype: object 16      2974676
# 519     2161558
# 1346    2130805
# 707     1724546
# 7       1126879
# 755     1061624
# 4        985920
# 1493     961794
# 178      878563
# 275      824451
# Name: rating_count_tot, dtype: int64 bar TOP 10 APPS ON THE BASIS OF TOTAL RATINGS APP NAME RATING COUNT (TOTAL)

# %%
print(Apple.cont_rating, None, "count", "COTNENT RAITNG", "NUMBER OF APP RATED",
           "DISTRIBUTION OF APPS ON THE BASIS OF CONTENT RATING", False)
# Out:
# 16       4+
# 519     12+
# 1346     9+
# 707      9+
# 7       12+
# 755     12+
# 4        4+
# 1493     4+
# 178     12+
# 275      4+
# 1246     9+
# 348      4+
# 343      4+
# 990      4+
# 3042     9+
# 1634    12+
# 1218     4+
# 1182    17+
# 1052     9+
# 47       4+
# 265      4+
# 829      4+
# 53       4+
# 1104     4+
# 12      17+
# 1775     9+
# 971     12+
# 45       4+
# 302      9+
# 1676     4+
#        ...
# 6470    17+
# 4380    17+
# 6471     9+
# 4340     4+
# 2862     9+
# 4341    17+
# 6475     4+
# 2835     4+
# 2827    17+
# 4350    17+
# 2812     4+
# 6485     4+
# 2808     4+
# 2807     4+
# 2802     4+
# 4358     4+
# 2796     4+
# 5797     9+
# 4363    17+
# 6494     4+
# 6495     4+
# 6496    12+
# 2786     4+
# 5793    17+
# 2781     4+
# 4366    17+
# 4371    12+
# 4373     4+
# 5788     4+
# 3597     4+
# ...

# %%
print(-60)
# Out:
# -60

# %%
print(Apple.cont_rating,"RATINGS ON APP STORE", "NUMBER OF APPS RATED")
# Out:
# 16       4+
# 519     12+
# 1346     9+
# 707      9+
# 7       12+
# 755     12+
# 4        4+
# 1493     4+
# 178     12+
# 275      4+
# 1246     9+
# 348      4+
# 343      4+
# 990      4+
# 3042     9+
# 1634    12+
# 1218     4+
# 1182    17+
# 1052     9+
# 47       4+
# 265      4+
# 829      4+
# 53       4+
# 1104     4+
# 12      17+
# 1775     9+
# 971     12+
# 45       4+
# 302      9+
# 1676     4+
#        ...
# 6470    17+
# 4380    17+
# 6471     9+
# 4340     4+
# 2862     9+
# 4341    17+
# 6475     4+
# 2835     4+
# 2827    17+
# 4350    17+
# 2812     4+
# 6485     4+
# 2808     4+
# 2807     4+
# 2802     4+
# 4358     4+
# 2796     4+
# 5797     9+
# 4363    17+
# 6494     4+
# 6495     4+
# 6496    12+
# 2786     4+
# 5793    17+
# 2781     4+
# 4366    17+
# 4371    12+
# 4373     4+
# 5788     4+
# 3597     4+
# Name: cont_rating, Length: 7197, dtype: object RATINGS ON APP STORE NUMBER OF APPS RATED

# %%
Apple[Apple.cont_rating=='4+']

# %%
Apple[Apple.cont_rating=='9+']
# Out:
#               id                                      track_name  size_bytes  \
# 1346   529479190                                  Clash of Clans   116476928
# 707    420009108                                      Temple Run    65921024
# 1246   512939461                                  Subway Surfers   156038144
# 3042   924373886             Crossy Road - Endless Arcade Hopper   165471232
# 1052   479516143                       Minecraft: Pocket Edition   147787776
# 1775   596402997                      Despicable Me: Minion Rush   147123200
# 302    350642635                              Plants vs. Zombies   105379840
# 925    457446957                                 Jetpack Joyride   108813312
# 1613   572395608                                    Temple Run 2   158025728
# 1781   597986893                           Plants vs. Zombies™ 2    98507776
# 4613  1053012308                                    Clash Royale   114408448
# ...

# %%
Apple[Apple.cont_rating=='17+']
# Out:
#               id                                         track_name  \
# 1182   500116670                                 Clear Vision (17+)
# 12     284815942               Google – Search made just for mobile
# 3086   930574573         Sniper 3D Assassin: Shoot to Kill Gun Game
# 221    333903271                                            Twitter
# 92     305343404                                             Tumblr
# 1433   544007664    YouTube - Watch Videos, Music, and Live Streams
# 197    328415391                               Yahoo Fantasy Sports
# 86     303849934                                     Beer Pong Game
# 1682   583222866                                Deer Hunter Classic
# 624    406719683                                           GasBuddy
# 1462   547702041                                             Tinder
# 1817   606190854                                         Iron Force
# 999    471063940                    Call of Duty: Black Ops Zombies
# ...

# %%
Apple[Apple.cont_rating=='12+']
# Out:
#               id                                         track_name  \
# 519    389801252                                          Instagram
# 7      284035177                            Pandora - Music & Radio
# 755    429047995                                          Pinterest
# 178    324684580                                      Spotify Music
# 1634   575658129                           Injustice: Gods Among Us
# 971    466965151                                 The Sims™ FreePlay
# 317    352683833   Groupon - Deals, Coupons & Discount Shopping App
# 719    422667065                    Tiny Tower - Free City Building
# 18     284993459  Shazam - Discover music, artists, videos & lyrics
# 2602   860822992                          Kim Kardashian: Hollywood
# 498    387428400                                     Infinity Blade
# 872    447188370                                           Snapchat
# 1933   640111933                                       Pixel Gun 3D
# ...
