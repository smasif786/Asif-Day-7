# %%
import pandas as pd
from sklearn.datasets import load_Cars
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-1-8de9e1708595> in <module>()
#       1 import pandas as pd
# ----> 2 from sklearn.datasets import load_Cars
#
# ImportError: cannot import name 'load_Cars' from 'sklearn.datasets' (C:\ProgramData\Anaconda3\lib\site-packages\sklearn\datasets\__init__.py)

# %%
Cars = load_Cars()
type(Cars)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-b07fe4b7aef9> in <module>()
# ----> 1 Cars = load_Cars()
#       2 type(Cars)
#
# NameError: name 'load_Cars' is not defined

# %%
from IPython.display import Image
Image(r"D:\SM ASIF Song\Photos\47076_390939394312308_1430901937_n.jpg")

# %%
Image(r"D:\SM ASIF Song\Photos\47076_390939394312308_1430901937_n.jpg")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-760f7fc588fb> in <module>()
# ----> 1 Image(r"D:\SM ASIF Song\Photos\47076_390939394312308_1430901937_n.jpg")
#
# NameError: name 'Image' is not defined

# %% [markdown]
# <D:\SM ASIF Song\Photos\47076_390939394312308_1430901937_n="47076_390939394312308_1430901937_n.jpg">

# %% [markdown]
# <img src="C:\Users\HOME\As.png">

# %% [markdown]
# <img src='As.png'/>

# %% [markdown]
# ![alt text](As.png "Title")

# %% [markdown]
# ![As.png](As.png)

# %% [markdown]
# ![title](As.png)

# %% [markdown]
# ![](As.png)

# %% [markdown]
# ![caption](As.png)
